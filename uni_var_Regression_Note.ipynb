# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("practice_data/Salary_dataset.csv") 
x = np.array(data.YearsExperience) 
y = np.array(data.Salary)
w = 0
b = 0

# %%
def linearReg(x, w, b):
    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m): 
        f_wb[i] = w * x[i] + b
    return f_wb

# %%
def costFun(x, y, w, b):
    m = x.shape[0]
    size = 1 / (2 * m)
    tmp_error = np.zeros(m)
    for i in range(m): 

        tmp_error[i] = (((w * x[i] + b) - y[i])**2)
    total = np.sum(tmp_error)
    mae = size * total
    return mae

# %%
def gradientDec(w, b, x, y, rate):
    m = len(x)
    for i in range(m):
        tmp_w = w - rate * (((w * x[i] + b) - y[i]) * x[i])
        tmp_b = b - rate * ((w * x[i] + b) - y[i])
        w = tmp_w
        b = tmp_b
    
    return w, b

# %%
def r_squared(y, y_hat):
    res_sum = np.sum((y - y_hat) ** 2)
    total_sum = np.sum((y - np.mean(y))  ** 2)
    cof_d = 1 - (res_sum/total_sum)
    return cof_d

# %%
learning_rate = 0.001
epoch = 1000
for i in range(epoch): 
    w, b = gradientDec(w,b,x,y,learning_rate)
    if i % 50 == 0: 
        print(f"Epoch: {i}: \t w: {w} \t b: {b}")
print(w,b)
y_hat = linearReg(x,w,b)
print(f"\nR^2: {r_squared(y, y_hat)}")
# Out:
# Epoch: 0: 	 w: 9374.201650264238 	 b: 25205.03460087986
# Epoch: 50: 	 w: 9374.198182068465 	 b: 25205.061584718256
# Epoch: 100: 	 w: 9374.19563381132 	 b: 25205.081411095824
# Epoch: 150: 	 w: 9374.193761479155 	 b: 25205.09597852852
# Epoch: 200: 	 w: 9374.192385782942 	 b: 25205.106681950885
# Epoch: 250: 	 w: 9374.191374990023 	 b: 25205.11454629145
# Epoch: 300: 	 w: 9374.190632309845 	 b: 25205.12032461633
# Epoch: 350: 	 w: 9374.190086625516 	 b: 25205.12457024104
# Epoch: 400: 	 w: 9374.189685683908 	 b: 25205.127689714216
# Epoch: 450: 	 w: 9374.189391092023 	 b: 25205.12998174739
# Epoch: 500: 	 w: 9374.189174640613 	 b: 25205.13166581895
# Epoch: 550: 	 w: 9374.189015602917 	 b: 25205.132903190704
# Epoch: 600: 	 w: 9374.188898749955 	 b: 25205.133812349708
# Epoch: 650: 	 w: 9374.188812892235 	 b: 25205.134480354332
# Epoch: 700: 	 w: 9374.188749808272 	 b: 25205.134971170777
# Epoch: 750: 	 w: 9374.188703457323 	 b: 25205.135331798203
# Epoch: 800: 	 w: 9374.188669400957 	 b: 25205.135596769247
# Epoch: 850: 	 w: 9374.188644378039 	 b: 25205.135791456738
# Epoch: 900: 	 w: 9374.18862599245 	 b: 25205.135934503392
# Epoch: 950: 	 w: 9374.188612483635 	 b: 25205.136039606943
# 9374.188602728036 25205.136115509093
#
# R^2: 0.9568912326708229

# %%
plt.plot(x, linearReg(x,w, b), c='b')
plt.xlabel("Years Expereince")
plt.ylabel("Salary($)")
plt.scatter(x, y, c='r' ,marker='x')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def model_version(x, y):
    print("-------")
    from sklearn.linear_model import LinearRegression
    from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
    model = LinearRegression()
    model.fit(x.reshape(-1, 1), y)
    
    new_sal = np.array([[69000]])
    y_pred = model.predict(x.reshape(-1, 1))
    predicted_price = model.predict(new_sal)
    
    mse = mean_squared_error(y, y_pred)
    print("Mean Squared Error:", mse)
    mae = mean_absolute_error(y, y_pred)
    print("Mean Absolute Error:", mae)
    print(r2_score(y,y_pred))
    print(predicted_price)

    plt.scatter(x, y, c='r', marker='x')
    plt.plot(x, y_pred)
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.title("Linear Regression Fit")
    plt.show()

# %%
model_version(x,y)
# Out:
# -------
# Mean Squared Error: 31270951.722280957
# Mean Absolute Error: 4644.2012894435375
# 0.9569566641435086
# [6.52072248e+08]
